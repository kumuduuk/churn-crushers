# %%
import pandas as pd

# %%
df = pd.read_csv('data/cleaned_data/bankchurners.csv')

# %%
df['customer_status'].value_counts()
# Out:
# customer_status
# Existing Customer    7437
# Attrited Customer    1412
# Name: count, dtype: int64

# %%
# Filter by customer and save it as the new dataframe
df = df[df['customer_status'] == 'Existing Customer']

# %%
# Check new values. Matches up with existing customer count above
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7437 entries, 0 to 8844
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   clientnum               7437 non-null   int64
#  1   customer_status         7437 non-null   object
#  2   age                     7437 non-null   int64
#  3   gender                  7437 non-null   object
#  4   dependencies            7437 non-null   int64
#  5   education_level         7437 non-null   object
#  6   marital_status          7437 non-null   object
#  7   income_category         7437 non-null   object
#  8   card_category           7437 non-null   object
#  9   months_on_book          7437 non-null   int64
#  10  no_of_products          7437 non-null   int64
#  11  months_inactive_12_mon  7437 non-null   int64
#  12  contacts_count_12_mon   7437 non-null   int64
#  13  credit_limit            7437 non-null   float64
# ...

# %%
# Export new dataframe - Attrited customers
df.to_csv('data/cleaned_data/existing_customers.csv')
