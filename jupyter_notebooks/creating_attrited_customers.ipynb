# %%
import pandas as pd

# %%
df = pd.read_csv('data/cleaned_data/bankchurners.csv')

# %% [markdown]
# As the split of the main dataset is roughly 83% existing customers and 17% attrited customers, we are going to divide our dataset into Attrited and Existing customers to see whether we can find any trends within those groups.

# %%
df['customer_status'].value_counts()
# Out:
# customer_status
# Existing Customer    7437
# Attrited Customer    1412
# Name: count, dtype: int64

# %%
# Filter by customer and save it as the new dataframe
df = df[df['customer_status'] == 'Attrited Customer']

# %%
# Check new values. All ok
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1412 entries, 14 to 8848
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   clientnum               1412 non-null   int64
#  1   customer_status         1412 non-null   object
#  2   age                     1412 non-null   int64
#  3   gender                  1412 non-null   object
#  4   dependencies            1412 non-null   int64
#  5   education_level         1412 non-null   object
#  6   marital_status          1412 non-null   object
#  7   income_category         1412 non-null   object
#  8   card_category           1412 non-null   object
#  9   months_on_book          1412 non-null   int64
#  10  no_of_products          1412 non-null   int64
#  11  months_inactive_12_mon  1412 non-null   int64
#  12  contacts_count_12_mon   1412 non-null   int64
#  13  credit_limit            1412 non-null   float64
# ...

# %%
# Export new dataframe - Attrited customers
df.to_csv('data/cleaned_data/attrited_customers.csv')
